# %% [markdown]
# Stable learning rates converge smoothly and avoid local minima, while large learning rates overshoot.
#
# I wonder if there exists a mathematical certainty of what is a global minimum. While I know that the second derivate = 0 shows you a
#
# (ADAM)
